# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# conda list

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 625

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    
#      city_url = f"{url}appid={api_key}&units={units}&q="
        
    city_url = url + "q=" + city + "&units=Metric" + "&APPID=" + weather_api_key
     
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | vargashi
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | tagusao
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | baghdad
# Processing Record 9 of Set 1 | catamarca
# Processing Record 10 of Set 1 | atherton
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | pangnirtung
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | nishihara
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | olafsvik
# Processing Record 19 of Set 1 | gamba
# Processing Record 20 of Set 1 | atar
# Processing Record 21 of Set 1 | dwarka
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | grindavik
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | gorontalo
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | adrar
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | snihurivka
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | marsa matruh
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | birao
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | paita
# Processing Record 43 of Set 1 | panorama
# Processing Record 44 of Set 1 | puerto del rosario
# Processing Record 45 of Set 1 | porto walter
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | sobolevo
# Processing Record 49 of Set 1 | udachnyy
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 0 of Set 2 | hermanus
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | coos bay
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | kingston
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | vila do maio
# Processing Record 12 of Set 2 | lata
# Processing Record 13 of Set 2 | zhangye
# Processing Record 14 of Set 2 | chapais
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | sorong
# Processing Record 19 of Set 2 | faya
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | quatre cocos
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | abasolo
# Processing Record 28 of Set 2 | santa helena
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | skibbereen
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 2 | cortez
# Processing Record 34 of Set 2 | kumphawapi
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | bilma
# Processing Record 37 of Set 2 | russell
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | lunel
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | yuanping
# Processing Record 44 of Set 2 | estevan
# Processing Record 45 of Set 2 | alice springs
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | vanimo
# Processing Record 48 of Set 2 | fairbanks
# Processing Record 49 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 0 of Set 3 | port macquarie
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | iquitos
# Processing Record 3 of Set 3 | bucerias
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | muroto
# Processing Record 7 of Set 3 | tuy hoa
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | los llanos de aridane
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | basco
# Processing Record 19 of Set 3 | xai-xai
# Processing Record 20 of Set 3 | puksoozero
# Processing Record 21 of Set 3 | palu
# Processing Record 22 of Set 3 | richards bay
# Processing Record 23 of Set 3 | biltine
# Processing Record 24 of Set 3 | stryn
# Processing Record 25 of Set 3 | roblin
# Processing Record 26 of Set 3 | barra do garcas
# Processing Record 27 of Set 3 | pala
# Processing Record 28 of Set 3 | san cristobal
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | kulhudhuffushi
# Processing Record 32 of Set 3 | tobol
# Processing Record 33 of Set 3 | rio cuarto
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | hobe sound
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | mariestad
# Processing Record 38 of Set 3 | aasiaat
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | acarau
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | vila franca do campo
# Processing Record 45 of Set 3 | santiago del estero
# Processing Record 46 of Set 3 | cap estate
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 0 of Set 4 | souris
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | namatanai
# Processing Record 3 of Set 4 | haines junction
# Processing Record 4 of Set 4 | huamachuco
# Processing Record 5 of Set 4 | vigrestad
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | harper
# Processing Record 12 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 4 | lazaro cardenas
# Processing Record 14 of Set 4 | college
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | plettenberg bay
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | the valley
# Processing Record 19 of Set 4 | xam nua
# Processing Record 20 of Set 4 | mantua
# Processing Record 21 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | almaznyy
# Processing Record 24 of Set 4 | piney green
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | maniitsoq
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | cazaje
# City not found. Skipping...
# Processing Record 29 of Set 4 | kedrovyy
# Processing Record 30 of Set 4 | majene
# Processing Record 31 of Set 4 | ararat
# Processing Record 32 of Set 4 | caravelas
# Processing Record 33 of Set 4 | joao pinheiro
# Processing Record 34 of Set 4 | sibu
# Processing Record 35 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 36 of Set 4 | rexburg
# Processing Record 37 of Set 4 | egvekinot
# Processing Record 38 of Set 4 | rosarito
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | valparaiso
# Processing Record 42 of Set 4 | keuruu
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | borba
# Processing Record 46 of Set 4 | waldkirch
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | praia da vitoria
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 0 of Set 5 | yellowknife
# Processing Record 1 of Set 5 | lorengau
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | cuervos
# Processing Record 4 of Set 5 | linxia
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | hastings
# Processing Record 7 of Set 5 | butaritari
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | vercelli
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | brokopondo
# Processing Record 12 of Set 5 | ruidoso
# Processing Record 13 of Set 5 | novoagansk
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | shingu
# Processing Record 16 of Set 5 | half moon bay
# Processing Record 17 of Set 5 | port lincoln
# Processing Record 18 of Set 5 | mayo
# Processing Record 19 of Set 5 | kingman
# Processing Record 20 of Set 5 | el bagre
# Processing Record 21 of Set 5 | matara
# Processing Record 22 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 5 | kapenguria
# Processing Record 24 of Set 5 | morlaix
# Processing Record 25 of Set 5 | svetlaya
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | gizo
# Processing Record 28 of Set 5 | troitsko-pechorsk
# Processing Record 29 of Set 5 | krasne
# Processing Record 30 of Set 5 | boguchany
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | osorno
# Processing Record 33 of Set 5 | sinnamary
# Processing Record 34 of Set 5 | omsukchan
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 37 of Set 5 | gat
# Processing Record 38 of Set 5 | usinsk
# Processing Record 39 of Set 5 | mahon
# Processing Record 40 of Set 5 | tutoia
# Processing Record 41 of Set 5 | san patricio
# Processing Record 42 of Set 5 | darbhanga
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | mayya
# Processing Record 45 of Set 5 | providencia
# Processing Record 46 of Set 5 | hirara
# Processing Record 47 of Set 5 | uribia
# Processing Record 48 of Set 5 | tara
# Processing Record 49 of Set 5 | ulyanovo
# City not found. Skipping...
# Processing Record 0 of Set 6 | izumo
# Processing Record 1 of Set 6 | nago
# Processing Record 2 of Set 6 | kumeny
# Processing Record 3 of Set 6 | khani
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | ketchikan
# Processing Record 6 of Set 6 | kologriv
# Processing Record 7 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 6 | port alfred
# Processing Record 9 of Set 6 | kurilsk
# Processing Record 10 of Set 6 | bayan
# Processing Record 11 of Set 6 | neiafu
# Processing Record 12 of Set 6 | shellbrook
# Processing Record 13 of Set 6 | gao
# Processing Record 14 of Set 6 | hami
# Processing Record 15 of Set 6 | chalmette
# Processing Record 16 of Set 6 | doraha
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | murgab
# Processing Record 20 of Set 6 | barstow
# Processing Record 21 of Set 6 | ngunguru
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | lang son
# Processing Record 24 of Set 6 | konyshevka
# Processing Record 25 of Set 6 | swan river
# Processing Record 26 of Set 6 | chingirlau
# Processing Record 27 of Set 6 | mataram
# Processing Record 28 of Set 6 | bitkine
# Processing Record 29 of Set 6 | assiniboia
# Processing Record 30 of Set 6 | columbus
# Processing Record 31 of Set 6 | caceres
# Processing Record 32 of Set 6 | waingapu
# Processing Record 33 of Set 6 | nyurba
# Processing Record 34 of Set 6 | blagoveshchensk
# Processing Record 35 of Set 6 | doka
# Processing Record 36 of Set 6 | okoneshnikovo
# Processing Record 37 of Set 6 | kemijarvi
# Processing Record 38 of Set 6 | voh
# Processing Record 39 of Set 6 | belmonte
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | mittagong
# Processing Record 42 of Set 6 | cabedelo
# Processing Record 43 of Set 6 | ponta do sol
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | kez
# Processing Record 46 of Set 6 | candido de abreu
# Processing Record 47 of Set 6 | elmira
# Processing Record 48 of Set 6 | ariquemes
# Processing Record 49 of Set 6 | limpapa
# Processing Record 0 of Set 7 | taksimo
# Processing Record 1 of Set 7 | lakes entrance
# Processing Record 2 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 7 | leh
# Processing Record 4 of Set 7 | kendari
# Processing Record 5 of Set 7 | lichinga
# Processing Record 6 of Set 7 | kjollefjord
# Processing Record 7 of Set 7 | faanui
# Processing Record 8 of Set 7 | orissaare
# Processing Record 9 of Set 7 | mareeba
# Processing Record 10 of Set 7 | airai
# Processing Record 11 of Set 7 | panguipulli
# Processing Record 12 of Set 7 | rayagada
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | todos santos
# Processing Record 15 of Set 7 | netarhat
# Processing Record 16 of Set 7 | mancio lima
# Processing Record 17 of Set 7 | port moresby
# Processing Record 18 of Set 7 | landeck
# Processing Record 19 of Set 7 | ha giang
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | aksarka
# Processing Record 24 of Set 7 | ambulu
# Processing Record 25 of Set 7 | angoche
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | daru
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | aguimes
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | quthing
# Processing Record 32 of Set 7 | alpena
# Processing Record 33 of Set 7 | roccastrada
# Processing Record 34 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | sechura
# Processing Record 37 of Set 7 | mzimba
# Processing Record 38 of Set 7 | evensk
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | bolkhov
# Processing Record 43 of Set 7 | luderitz
# Processing Record 44 of Set 7 | konstantinovka
# Processing Record 45 of Set 7 | nanortalik
# Processing Record 46 of Set 7 | broken hill
# Processing Record 47 of Set 7 | nova gradiska
# Processing Record 48 of Set 7 | ixtapa
# Processing Record 49 of Set 7 | vengerovo
# Processing Record 0 of Set 8 | shelburne
# Processing Record 1 of Set 8 | dayong
# Processing Record 2 of Set 8 | port blair
# Processing Record 3 of Set 8 | benjamin constant
# Processing Record 4 of Set 8 | fontenay-le-comte
# Processing Record 5 of Set 8 | lodja
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | huanuco
# Processing Record 8 of Set 8 | aviles
# Processing Record 9 of Set 8 | butterworth
# Processing Record 10 of Set 8 | kholodnyy
# Processing Record 11 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 8 | russkoye
# Processing Record 13 of Set 8 | walvis bay
# Processing Record 14 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 8 | cedar city
# Processing Record 16 of Set 8 | xining
# Processing Record 17 of Set 8 | praya
# Processing Record 18 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 8 | luwuk
# Processing Record 20 of Set 8 | qaqortoq
# Processing Record 21 of Set 8 | srandakan
# Processing Record 22 of Set 8 | tura
# Processing Record 23 of Set 8 | mkuranga
# Processing Record 24 of Set 8 | lucan
# Processing Record 25 of Set 8 | tocopilla
# Processing Record 26 of Set 8 | weligama
# Processing Record 27 of Set 8 | burica
# City not found. Skipping...
# Processing Record 28 of Set 8 | andros town
# Processing Record 29 of Set 8 | constitucion
# Processing Record 30 of Set 8 | cotoca
# Processing Record 31 of Set 8 | rumphi
# Processing Record 32 of Set 8 | lensk
# Processing Record 33 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 8 | sorland
# Processing Record 35 of Set 8 | sambava
# Processing Record 36 of Set 8 | veraval
# Processing Record 37 of Set 8 | puerto padre
# Processing Record 38 of Set 8 | kaeo
# Processing Record 39 of Set 8 | fort nelson
# Processing Record 40 of Set 8 | vanavara
# Processing Record 41 of Set 8 | stralsund
# Processing Record 42 of Set 8 | subate
# Processing Record 43 of Set 8 | rondonopolis
# Processing Record 44 of Set 8 | avera
# Processing Record 45 of Set 8 | noumea
# Processing Record 46 of Set 8 | amahai
# Processing Record 47 of Set 8 | itarema
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | hambantota
# Processing Record 0 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 9 | rawson
# Processing Record 2 of Set 9 | pelham
# Processing Record 3 of Set 9 | yeppoon
# Processing Record 4 of Set 9 | argelia
# Processing Record 5 of Set 9 | lenexa
# Processing Record 6 of Set 9 | vyazma
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | cap-aux-meules
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | honningsvag
# Processing Record 11 of Set 9 | kambam
# Processing Record 12 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 9 | bagua grande
# Processing Record 14 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 9 | marathon
# Processing Record 16 of Set 9 | launceston
# Processing Record 17 of Set 9 | jaru
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | maracaibo
# Processing Record 20 of Set 9 | nouakchott
# Processing Record 21 of Set 9 | eagle pass
# Processing Record 22 of Set 9 | hammerfest
# Processing Record 23 of Set 9 | suntar
# Processing Record 24 of Set 9 | malanje
# Processing Record 25 of Set 9 | jacareacanga
# Processing Record 26 of Set 9 | shebalino
# Processing Record 27 of Set 9 | eyrarbakki
# Processing Record 28 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 9 | inhambane
# Processing Record 30 of Set 9 | sebinkarahisar
# Processing Record 31 of Set 9 | khandyga
# Processing Record 32 of Set 9 | roebourne
# Processing Record 33 of Set 9 | pueblo
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | coaraci
# Processing Record 36 of Set 9 | dzhebariki-khaya
# Processing Record 37 of Set 9 | beloha
# Processing Record 38 of Set 9 | itoman
# Processing Record 39 of Set 9 | marsh harbour
# Processing Record 40 of Set 9 | saint george
# Processing Record 41 of Set 9 | freeport
# Processing Record 42 of Set 9 | alihe
# Processing Record 43 of Set 9 | umm lajj
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | port hedland
# Processing Record 46 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 47 of Set 9 | beringovskiy
# Processing Record 48 of Set 9 | puerto escondido
# Processing Record 49 of Set 9 | puerto madryn
# Processing Record 0 of Set 10 | auki
# Processing Record 1 of Set 10 | panzhihua
# Processing Record 2 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 10 | pacifica
# Processing Record 4 of Set 10 | placido de castro
# Processing Record 5 of Set 10 | hiranagar
# Processing Record 6 of Set 10 | santana do livramento
# Processing Record 7 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | keti bandar
# Processing Record 9 of Set 10 | dali
# Processing Record 10 of Set 10 | san ramon de la nueva oran
# Processing Record 11 of Set 10 | angren
# Processing Record 12 of Set 10 | houma
# Processing Record 13 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 10 | saint-augustin
# Processing Record 15 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 16 of Set 10 | chibombo
# Processing Record 17 of Set 10 | hovd
# Processing Record 18 of Set 10 | jinchang
# Processing Record 19 of Set 10 | gold coast
# Processing Record 20 of Set 10 | qasigiannguit
# Processing Record 21 of Set 10 | gornyy
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | bonnyville
# Processing Record 24 of Set 10 | privolzhskiy
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | huarmey
# Processing Record 27 of Set 10 | dingle
# Processing Record 28 of Set 10 | kudahuvadhoo
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | george
# Processing Record 32 of Set 10 | nabire
# Processing Record 33 of Set 10 | sharjah
# Processing Record 34 of Set 10 | el tigre
# Processing Record 35 of Set 10 | ust-karsk
# Processing Record 36 of Set 10 | hasaki
# Processing Record 37 of Set 10 | hofn
# Processing Record 38 of Set 10 | itupiranga
# Processing Record 39 of Set 10 | slave lake
# Processing Record 40 of Set 10 | colchester
# Processing Record 41 of Set 10 | laguna
# Processing Record 42 of Set 10 | ossora
# Processing Record 43 of Set 10 | trelew
# Processing Record 44 of Set 10 | chaozhou
# Processing Record 45 of Set 10 | margate
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | jakar
# Processing Record 0 of Set 11 | taupo
# Processing Record 1 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 2 of Set 11 | jalu
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | havre-saint-pierre
# Processing Record 5 of Set 11 | limbazi
# Processing Record 6 of Set 11 | lokosovo
# Processing Record 7 of Set 11 | beruwala
# Processing Record 8 of Set 11 | salta
# Processing Record 9 of Set 11 | ribas do rio pardo
# Processing Record 10 of Set 11 | jiangkou
# Processing Record 11 of Set 11 | mizdah
# Processing Record 12 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 11 | asosa
# Processing Record 14 of Set 11 | katsuura
# Processing Record 15 of Set 11 | kawalu
# Processing Record 16 of Set 11 | marapanim
# Processing Record 17 of Set 11 | pedregulho
# Processing Record 18 of Set 11 | pak phanang
# Processing Record 19 of Set 11 | tame
# Processing Record 20 of Set 11 | humaita
# Processing Record 21 of Set 11 | binzhou
# Processing Record 22 of Set 11 | donskoy
# Processing Record 23 of Set 11 | marrakesh
# Processing Record 24 of Set 11 | amurzet
# Processing Record 25 of Set 11 | port-cartier
# Processing Record 26 of Set 11 | nioki
# Processing Record 27 of Set 11 | taltal
# Processing Record 28 of Set 11 | kisangani
# Processing Record 29 of Set 11 | niquero
# Processing Record 30 of Set 11 | naron
# Processing Record 31 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 11 | west monroe
# Processing Record 33 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | oxapampa
# Processing Record 36 of Set 11 | ust-maya
# Processing Record 37 of Set 11 | oranjemund
# Processing Record 38 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 11 | maun
# Processing Record 40 of Set 11 | svetlogorsk
# Processing Record 41 of Set 11 | gewane
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 11 | centerville
# Processing Record 45 of Set 11 | chinhoyi
# Processing Record 46 of Set 11 | srivardhan
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | maceio
# Processing Record 49 of Set 11 | trat
# Processing Record 0 of Set 12 | berezovyy
# Processing Record 1 of Set 12 | jackson
# Processing Record 2 of Set 12 | kars
# Processing Record 3 of Set 12 | hanzhong
# Processing Record 4 of Set 12 | sayansk
# Processing Record 5 of Set 12 | alofi
# Processing Record 6 of Set 12 | portoferraio
# Processing Record 7 of Set 12 | harihar
# Processing Record 8 of Set 12 | torbat-e jam
# Processing Record 9 of Set 12 | coffs harbour
# Processing Record 10 of Set 12 | aklavik
# Processing Record 11 of Set 12 | saijo
# Processing Record 12 of Set 12 | anantapur
# Processing Record 13 of Set 12 | parrita
# Processing Record 14 of Set 12 | nakasongola
# Processing Record 15 of Set 12 | yumen
# Processing Record 16 of Set 12 | bayir
# Processing Record 17 of Set 12 | miles city
# Processing Record 18 of Set 12 | dicabisagan
# Processing Record 19 of Set 12 | shimoda
# Processing Record 20 of Set 12 | kuppam
# Processing Record 21 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 12 | gayeri
# Processing Record 23 of Set 12 | tabas
# Processing Record 24 of Set 12 | sangar
# Processing Record 25 of Set 12 | bom jardim
# Processing Record 26 of Set 12 | grahamstown
# Processing Record 27 of Set 12 | romuli
# Processing Record 28 of Set 12 | lagoa
# Processing Record 29 of Set 12 | conde
# Processing Record 30 of Set 12 | mahajanga
# Processing Record 31 of Set 12 | nong khai
# Processing Record 32 of Set 12 | fortuna foothills
# Processing Record 33 of Set 12 | nicoya
# Processing Record 34 of Set 12 | pimentel
# Processing Record 35 of Set 12 | waddan
# Processing Record 36 of Set 12 | lanigan
# Processing Record 37 of Set 12 | tortoli
# Processing Record 38 of Set 12 | ambilobe
# Processing Record 39 of Set 12 | nyrob
# Processing Record 40 of Set 12 | manzini
# Processing Record 41 of Set 12 | namangan
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | mangan
# Processing Record 44 of Set 12 | narsaq
# Processing Record 45 of Set 12 | cepu
# Processing Record 46 of Set 12 | lac-megantic
# Processing Record 47 of Set 12 | north bend
# Processing Record 48 of Set 12 | mudgee
# Processing Record 49 of Set 12 | vostok
# Processing Record 0 of Set 13 | itapaci
# Processing Record 1 of Set 13 | prokopyevsk
# Processing Record 2 of Set 13 | turbat
# Processing Record 3 of Set 13 | yerbogachen
# Processing Record 4 of Set 13 | talavera de la reina
# Processing Record 5 of Set 13 | naila
# Processing Record 6 of Set 13 | abnub
# Processing Record 7 of Set 13 | road town
# Processing Record 8 of Set 13 | batagay
# Processing Record 9 of Set 13 | yulara
# Processing Record 10 of Set 13 | merritt island
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | kanniyakumari
# Processing Record 13 of Set 13 | thinadhoo
# Processing Record 14 of Set 13 | coihaique
# Processing Record 15 of Set 13 | chanderi
# Processing Record 16 of Set 13 | sheopur
# Processing Record 17 of Set 13 | sibolga
# Processing Record 18 of Set 13 | kasungu
# Processing Record 19 of Set 13 | port hueneme
# Processing Record 20 of Set 13 | jumla
# Processing Record 21 of Set 13 | revda
# Processing Record 22 of Set 13 | bocaiuva
# Processing Record 23 of Set 13 | taikang
# Processing Record 24 of Set 13 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  cape town -33.9258   18.4232     22.99        89          75        6.17
# 1   vargashi  55.3556   65.8467    -17.21        99          95        2.03
# 2       naze  28.3667  129.4833     21.51        78          48        8.03
# 3     atuona  -9.8000 -139.0333     25.84        81          28        7.28
# 4    tagusao   9.1924  117.8141     27.60        77          47        2.88
#
#   Country        Date
# 0      ZA  1675743815
# 1      RU  1675743815
# 2      JP  1675743816
# 3      PF  1675743816
# 4      PH  1675743816

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        cape town -33.9258   18.4232     22.99        89          75
# 1         vargashi  55.3556   65.8467    -17.21        99          95
# 2             naze  28.3667  129.4833     21.51        78          48
# 3           atuona  -9.8000 -139.0333     25.84        81          28
# 4          tagusao   9.1924  117.8141     27.60        77          47
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      ZA  1675743815
# 1              2.03      RU  1675743815
# 2              8.03      JP  1675743816
# 3              7.28      PF  1675743816
# 4              2.88      PH  1675743816

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='blue')

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs Temperature({pd.to_datetime(city_date, unit='s').date()}")
plt.xlabel('latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='blue')

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({pd.to_datetime(city_date, unit='s').date()})")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
width = 480
height = 640
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='blue')

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({pd.to_datetime(city_date, unit='s').date()})")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='blue')

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({pd.to_datetime(city_date, unit='s').date()})")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed  (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg_plot( x_values, y_values, z_text_coord, y_label):
    
   
 # create the linear regression
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
       
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values, color="blue")
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    
    plt.annotate(line_eq, z_text_coord, fontsize=15,color="red")
# print the r_alue 
    print(f"The r-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
Northen_hemisphere_df = city_data_df[city_data_df["Lat"]>=0]

# Display sample data
Northen_hemisphere_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        vargashi  55.3556   65.8467    -17.21        99          95
# 2            naze  28.3667  129.4833     21.51        78          48
# 4         tagusao   9.1924  117.8141     27.60        77          47
# 7         baghdad  33.3406   44.4009     10.95        66         100
# 9        atherton  53.5237   -2.4935      4.12        87          99
#
#          Wind Speed Country        Date
# City_ID
# 1              2.03      RU  1675743815
# 2              8.03      JP  1675743816
# 4              2.88      PH  1675743816
# 7              3.60      IQ  1675743626
# 9              1.75      GB  1675743819

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        cape town -33.9258   18.4232     22.99        89          75
# 3           atuona  -9.8000 -139.0333     25.84        81          28
# 5        mahebourg -20.4081   57.7000     27.92        78          75
# 6         saldanha -33.0117   17.9442     18.47        95          99
# 8        catamarca -28.4696  -65.7852     28.76        40           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      ZA  1675743815
# 3              7.28      PF  1675743816
# 5              4.12      MU  1675743817
# 6              6.50      ZA  1675743817
# 8              0.89      AR  1675743660

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = Northen_hemisphere_df["Lat"]
y_values = Northen_hemisphere_df["Max Temp"]
linear_reg_plot(x_values, y_values, (5.8, 0.8)," Max Temp")
# Out:
# The r-value is: -0.8767832933208966

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

linear_reg_plot(x_values, y_values, (-48, 8), " Max Temp")
# Out:
# The r-value is: 0.41646877955592093

# %% [markdown]
# **Discussion about the linear relationship:** in these two plots, we constate a significant linear relationship betwenn these two. the r-value give a negative direction

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = Northen_hemisphere_df["Lat"]
y_values = Northen_hemisphere_df["Humidity"]
linear_reg_plot(x_values, y_values, (7, 17), "Humidity")
# Out:
# The r-value is: 0.4629873793991901

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
linear_reg_plot(x_values, y_values, (-48, 8), "Humidity")
# Out:
# The r-value is: 0.259460780072736

# %% [markdown]
# **Discussion about the linear relationship:** the relationship between these two plots is moderate, the r-value is on the negative direction,  and the humidity is more significant on nothern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = Northen_hemisphere_df["Lat"]
y_values = Northen_hemisphere_df["Cloudiness"]
linear_reg_plot(x_values, y_values, (5.8, 0.8),"Cloudiness")
# Out:
# The r-value is: 0.2704614503509268

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
linear_reg_plot(x_values, y_values, (-45, 10),"Cloudiness")
# Out:
# The r-value is: 0.4349143327740676

# %% [markdown]
# **Discussion about the linear relationship:** according to the plot above there not a major relationship between the cloudiness column and the latitude, but we constate getting more cloud when considere the southen_hemisphere dataFrame.

# %%
# Northern Hemisphere
x_values = Northen_hemisphere_df["Lat"]
y_values = Northen_hemisphere_df["Wind Speed"]
linear_reg_plot(x_values, y_values, (5.8, 0.8),"Wind Speed")
# Out:
# The r-value is: -0.010048918132838192

# %%
#Cloudiness vs. Latitude Linear Regression Plot

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
linear_reg_plot(x_values, y_values, (-50, 1),"Wind Speed")
# Out:
# The r-value is: -0.34012065250529805

# %% [markdown]
# **Discussion about the linear relationship:**  latitude increases in the northern hemisphere compere to southern hemisphere, wind speed slightly increases compare to nothern hemisphere.
